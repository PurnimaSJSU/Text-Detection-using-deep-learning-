# %%
import pytesseract
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
import cv2
img = cv2.imread(r"C:\Users\Jashwanth\Documents\Data mining\Project\data\test\t10.jpeg")
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

img = cv2.imread(r"C:\Users\Jashwanth\Documents\Data mining\Project\data\test\t10.jpeg",0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(pytesseract.image_to_string(img))

# %%
# down_width = 160
# down_height = 40
# down_points = (down_width, down_height)
# img = cv2.resize(img, down_points, interpolation= cv2.INTER_LINEAR)
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
def noise_removal(image):
    import numpy as np
    kernel = np.ones((1, 1), np.uint8)
    image = cv2.dilate(image, kernel, iterations=1)
    kernel = np.ones((1, 1), np.uint8) 
    image = cv2.erode(image, kernel, iterations=1)
    image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    image = cv2.medianBlur(image, 3)
    return (image)
img = cv2.imread(r"C:\Users\Jashwanth\Documents\Data mining\Project\data\test\t10.jpeg",0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(pytesseract.image_to_string(img))


blur = cv2.GaussianBlur(img, (3,3), 0)
cv2.imshow("b",blur)
cv2.waitKey(0)
cv2.destroyAllWindows()
data = pytesseract.image_to_string(blur, lang='eng', config='--psm 7')
print(data)

no_noise = noise_removal(img)
blur = noise_removal(no_noise)
cv2.imshow("n",no_noise)
cv2.waitKey(0)
cv2.destroyAllWindows()
data = pytesseract.image_to_string(blur, lang='eng', config='--psm 7')
print(data)

thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
cv2.imshow("t",thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()
data = pytesseract.image_to_string(thresh, lang='eng', config='--psm 7')
print(data)
adap_thrs = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,91,31)
cv2.imshow("adap",adap_thrs)
cv2.waitKey(0)
cv2.destroyAllWindows()
data = pytesseract.image_to_string(adap_thrs, lang='eng', config='--psm 7')
print(data)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)
invert = 255 - opening
data = pytesseract.image_to_string(invert, lang='eng', config='--psm 7')
print(data)
cv2.destroyAllWindows()

# %%
no_filter = []
blur1 = []
thres = []
adap_thres = []
inverted = []
noise_removed = []

# %%
import numpy as np

def noise_removal(image):
    kernel = np.ones((1, 1), np.uint8)
    image = cv2.dilate(image, kernel, iterations=1)
    kernel = np.ones((1, 1), np.uint8)
    image = cv2.erode(image, kernel, iterations=1)
    image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    image = cv2.medianBlur(image, 3)
    return (image)

# %%
import os, glob
import cv2
images = [cv2.imread(file,0) for file in glob.glob(r'C:\Users\Jashwanth\Documents\Data mining\Project\data\test/*.jpg')]
for i in images:
#     img = cv2.imread(r"C:\Users\Jashwanth\Documents\Data mining\Project\data\test\t10.jpeg",0)
#     cv2.imshow('image',img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    data = pytesseract.image_to_string(i, lang='eng', config='--psm 7')
#     print(data)
    no_filter.append(data.rstrip())
    
    
    blur = cv2.GaussianBlur(i, (3,3), 0)
#     cv2.imshow("blurred_image",blur)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    data = pytesseract.image_to_string(blur, lang='eng', config='--psm 7')
#     print(data)
    blur1.append(data.rstrip())
    
    
    
    thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
#     cv2.imshow("threshold_image",thresh)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    data = pytesseract.image_to_string(thresh, lang='eng', config='--psm 7')
#     print(data)
    thres.append(data.rstrip())
    
    adap_thrs = cv2.adaptiveThreshold(i,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,91,31)
#     cv2.imshow("adap_thresh_image",adap_thrs)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    data = pytesseract.image_to_string(adap_thrs, lang='eng', config='--psm 7')
#     print(data)
    adap_thres.append(data.rstrip())
    
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
    opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)
    invert = 255 - opening
#     cv2.imshow("inverted_image",invert)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    data = pytesseract.image_to_string(invert, lang='eng', config='--psm 7')
#     print(data)
    inverted.append(data.rstrip())
    
#     no_noise = noise_removal(i)
#     img = noise_removal(no_noise)
#     cv2.imshow("noise_removed_image",no_noise)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
#     data = pytesseract.image_to_string(img, lang='eng', config='--psm 7')
#     print(data)
#     noise_removed.append(data)

# %%
len(blur1)
# Out:
# 2001

# %%
# blur

# %%
import pandas as pd

# %%
nf = pd.DataFrame(no_filter)
nf = nf.replace('\n','', regex=True)
blr = pd.DataFrame(blur1)
blr = blr.replace('\n','', regex=True)
thrs = pd.DataFrame(thres)
thrs = thrs.replace('\n','', regex=True)
adap_th= pd.DataFrame(adap_thres)
adap_th = adap_th.replace('\n','', regex=True)
inver = pd.DataFrame(inverted)
inver = inver.replace('\n','', regex=True)

# %%
# blr.tail(40)

# %%
import pandas as pd
labels = pd.read_csv("labels.txt", sep=" ",names = ['labels'])
l = labels.head(2001)

# %%
from sklearn.metrics import accuracy_score
print("accuracy",accuracy_score(l,nf))
print("Blur accuracy",accuracy_score(l,blr))
print("Threshold accuracy",accuracy_score(l,thrs))
print("AdapThreshold accuracy",accuracy_score(l,adap_th))
print("Inverted accuracy",accuracy_score(l,inver))
# Out:
# accuracy 0.5322338830584707
# Blur accuracy 0.553223388305847
# Threshold accuracy 0.5402298850574713
# AdapThreshold accuracy 0.26936531734132935
# Inverted accuracy 0.47426286856571714

# %%
no_noise = noise_removal(img)

# %%
display("temp/no_noise.jpg")

# %%
img = cv.imread(r"C:\Users\Jashwanth\Documents\Data mining\Project\data\images\00000117.jpg")
cv2.imshow('i',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# print(img)

# %%
nn = noise_removal(img)
cv2.imshow('nn',nn)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(nn)

# %%
coords = np.column_stack(np.where(thresh > 0))
angle = cv2.minAreaRect(coords)[-1]
# the `cv2.minAreaRect` function returns values in the
# range [-90, 0); as the rectangle rotates clockwise the
# returned angle trends to 0 -- in this special case we
# need to add 90 degrees to the angle
print(angle)
if angle < -45:
    angle = -(90 + angle)
# otherwise, just take the inverse of the angle to make
# it positive
else:
    angle = -angle

# %%
# rotate the image to deskew it
(h, w) = img.shape[:2]
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, angle, 1.0)
rotated = cv2.warpAffine(img, M, (w, h),
flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)

# %%
cv2.putText(rotated, "Angle: {:.2f} degrees".format(angle),(10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
# show the output image
print("[INFO] angle: {:.3f}".format(angle))
cv2.imshow("Input", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("Rotated", rotated)
cv2.waitKey(0)
cv2.destroyAllWindows()
